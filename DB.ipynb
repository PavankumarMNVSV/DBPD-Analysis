# %%
import pandas as pd
import random

# %%
ls
# Out:
# classes.txt  dbpedia_csv/        readme.txt  train.csv
# DB.ipynb     dbpedia_csv.tar.gz  test.csv

# %%
train_data = pd.read_csv("train.csv")
train_data
# Out:
#         target                              title  \
# 0            1                   E. D. Abbott Ltd
# 1            1                     Schwan-Stabilo
# 2            1                         Q-workshop
# 3            1  Marvell Software Solutions Israel
# 4            1        Bergan Mercy Medical Center
# ...        ...                                ...
# 559995      14                   Barking in Essex
# 559996      14                   Science & Spirit
# 559997      14             The Blithedale Romance
# 559998      14                Razadarit Ayedawbon
# 559999      14           The Vinyl Cafe Notebooks
#
#                                                   content
# 0        Abbott of Farnham E D Abbott Limited was a Br...
# 1        Schwan-STABILO is a German maker of pens for ...
# 2        Q-workshop is a Polish company located in Poz...
# 3        Marvell Software Solutions Israel known as RA...
# 4        Bergan Mercy Medical Center is a hospital loc...
# ...                                                   ...
# 559995   Barking in Essex is a Black comedy play direc...
# 559996   Science & Spirit is a discontinued American b...
# 559997   The Blithedale Romance (1852) is Nathaniel Ha...
# 559998   Razadarit Ayedawbon (Burmese: ရာဇာဓိရာဇ် အရေး...
# 559999   Vinyl Cafe Notebooks: a collection of essays ...
#
# [560000 rows x 3 columns]

# %%
test_data = pd.read_csv("test.csv")
test = test_data[['target','title','content']]
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
test
# Out:
#        target                     title  \
# 0           1                     TY KU
# 1           1     Odd Lot Entertainment
# 2           1                    Henkel
# 3           1                GOAT Store
# 4           1  RagWing Aircraft Designs
# ...       ...                       ...
# 69995      14            Energy Victory
# 69996      14                 Bestiario
# 69997      14         Wuthering Heights
# 69998      14             L'Indépendant
# 69999      14      The Prophecy (novel)
#
#                                                  content
# 0       TY KU /taɪkuː/ is an American alcoholic bever...
# 1       OddLot Entertainment founded in 2001 by longt...
# 2       Henkel AG & Company KGaA operates worldwide w...
# 3       The GOAT Store (Games Of All Type Store) LLC ...
# 4       RagWing Aircraft Designs (also called the Rag...
# ...                                                  ...
# 69995   Energy Victory: Winning the War on Terror by ...
# 69996   Bestiario is a book of 8 short stories writte...
# 69997   Wuthering Heights is a novel by Emily Brontë ...
# 69998   L'Indépendant is a newspaper published in Lux...
# 69999   The Prophecy is the fifth novel by New York T...
#
# [70000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
train_data.groupby('target').title.count().plot.bar(ylim=0)
train_data.shape
plt.show()

# %% [markdown]
# <h4>Data is not skewed towards one class.Its BALANCED.
# Because it is not biased we can use conventional algorithms.When biased those algorithms tend to go towards majority classes.

# %%
# taking a percentage of data
#p = 0.005
#train_data = pd.read_csv("train.csv",header=0,skiprows=lambda i: i>0 and random.random() > p)
#train_data
# should add column
#t_data["act_class"]
#with open("classes.txt") as classes:
#    act_class = classes.readlines()
#act_class
train_data
# Out:
#         target                              title  \
# 0            1                   E. D. Abbott Ltd
# 1            1                     Schwan-Stabilo
# 2            1                         Q-workshop
# 3            1  Marvell Software Solutions Israel
# 4            1        Bergan Mercy Medical Center
# ...        ...                                ...
# 559995      14                   Barking in Essex
# 559996      14                   Science & Spirit
# 559997      14             The Blithedale Romance
# 559998      14                Razadarit Ayedawbon
# 559999      14           The Vinyl Cafe Notebooks
#
#                                                   content
# 0        Abbott of Farnham E D Abbott Limited was a Br...
# 1        Schwan-STABILO is a German maker of pens for ...
# 2        Q-workshop is a Polish company located in Poz...
# 3        Marvell Software Solutions Israel known as RA...
# 4        Bergan Mercy Medical Center is a hospital loc...
# ...                                                   ...
# 559995   Barking in Essex is a Black comedy play direc...
# 559996   Science & Spirit is a discontinued American b...
# 559997   The Blithedale Romance (1852) is Nathaniel Ha...
# 559998   Razadarit Ayedawbon (Burmese: ရာဇာဓိရာဇ် အရေး...
# 559999   Vinyl Cafe Notebooks: a collection of essays ...
#
# [560000 rows x 3 columns]

# %% [markdown]
# <h4>Data Exploration : The given problem is an Multi-Class Text Classification.Total there are 14 unique classes in the given data.
#                    They are considered in the dataset in order to sort them.

# %% [markdown]
# <h5>Intially the data is sampled because the computation is taking more time(in terms of CPU),Later full_data is considered

# %%
train_data.loc[train_data['target'] == 1,'target_id'] = 'Company'
train_data.loc[train_data['target'] == 2,'target_id'] = 'EducationalInstitution'
train_data.loc[train_data['target'] == 3,'target_id'] = 'Artist'
train_data.loc[train_data['target'] == 4,'target_id'] = 'Athlete'
train_data.loc[train_data['target'] == 5,'target_id'] = 'OfficeHolder'
train_data.loc[train_data['target'] == 6,'target_id'] = 'MeanOfTransportation'
train_data.loc[train_data['target'] == 7,'target_id'] = 'Building'
train_data.loc[train_data['target'] == 8,'target_id'] = 'NaturalPlace'
train_data.loc[train_data['target'] == 9,'target_id'] = 'Village'
train_data.loc[train_data['target'] == 10,'target_id'] = 'Animal'
train_data.loc[train_data['target'] == 11,'target_id'] = 'Plant'
train_data.loc[train_data['target'] == 12,'target_id'] = 'Album'
train_data.loc[train_data['target'] == 13,'target_id'] = 'Film'
train_data.loc[train_data['target'] == 14,'target_id'] = 'WrittenWork'

# %%
train_data
# Out:
#         target                              title  \
# 0            1                   E. D. Abbott Ltd
# 1            1                     Schwan-Stabilo
# 2            1                         Q-workshop
# 3            1  Marvell Software Solutions Israel
# 4            1        Bergan Mercy Medical Center
# ...        ...                                ...
# 559995      14                   Barking in Essex
# 559996      14                   Science & Spirit
# 559997      14             The Blithedale Romance
# 559998      14                Razadarit Ayedawbon
# 559999      14           The Vinyl Cafe Notebooks
#
#                                                   content    target_id
# 0        Abbott of Farnham E D Abbott Limited was a Br...      Company
# 1        Schwan-STABILO is a German maker of pens for ...      Company
# 2        Q-workshop is a Polish company located in Poz...      Company
# 3        Marvell Software Solutions Israel known as RA...      Company
# 4        Bergan Mercy Medical Center is a hospital loc...      Company
# ...                                                   ...          ...
# 559995   Barking in Essex is a Black comedy play direc...  WrittenWork
# 559996   Science & Spirit is a discontinued American b...  WrittenWork
# 559997   The Blithedale Romance (1852) is Nathaniel Ha...  WrittenWork
# 559998   Razadarit Ayedawbon (Burmese: ရာဇာဓိရာဇ် အရေး...  WrittenWork
# 559999   Vinyl Cafe Notebooks: a collection of essays ...  WrittenWork
#
# [560000 rows x 4 columns]

# %% [markdown]
# <h2> Pre-Processing
#
# <h4>Removing the duplicates and Sorting them acc to Target Variables

# %%
from io import StringIO
col = ['target_id', 'content']
train_data = train_data[col]
train_data = train_data[pd.notnull(train_data['content'])]
train_data.columns = ['target_id', 'content']
train_data['target'] = train_data['target_id'].factorize()[0]
category_id_df = train_data[['target_id', 'target']].drop_duplicates().sort_values('target')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['target', 'target_id']].values)
train_data
# Out:
#           target_id                                            content  target
# 0           Company   Abbott of Farnham E D Abbott Limited was a Br...       0
# 1           Company   Schwan-STABILO is a German maker of pens for ...       0
# 2           Company   Q-workshop is a Polish company located in Poz...       0
# 3           Company   Marvell Software Solutions Israel known as RA...       0
# 4           Company   Bergan Mercy Medical Center is a hospital loc...       0
# ...             ...                                                ...     ...
# 559995  WrittenWork   Barking in Essex is a Black comedy play direc...      13
# 559996  WrittenWork   Science & Spirit is a discontinued American b...      13
# 559997  WrittenWork   The Blithedale Romance (1852) is Nathaniel Ha...      13
# 559998  WrittenWork   Razadarit Ayedawbon (Burmese: ရာဇာဓိရာဇ် အရေး...      13
# 559999  WrittenWork   Vinyl Cafe Notebooks: a collection of essays ...      13
#
# [560000 rows x 3 columns]

# %% [markdown]
# ROC-AUC curve

# %%
def roc_auc(predicted_data):
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    n_classes= 14
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(predicted_data))[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])


    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    lw=2
    plt.figure(figsize=(8,5))
    plt.plot(fpr["macro"], tpr["macro"],
             label='macro-average ROC curve (area = {0:0.2f})'
                   ''.format(roc_auc["macro"]),
             color='green', linestyle=':', linewidth=4)

    colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
    for i, color in zip(range(n_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=lw,
                 label='ROC curve of class {0} (area = {1:0.2f})'
                 ''.format(i, roc_auc[i]))

    plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.annotate('Random Guess',(.5,.48),color='red')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# <h3> Feature Extraction and Selection

# %% [markdown]
# <h5>Count Vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
X_train = train_data['content']
y_train = train_data['target_id']


count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
print(clf.predict(count_vect.transform([" The Vaidnei River is a tributary of the Scroafa River in Romania."])))
# Out:
# ['NaturalPlace']

# %%
test.loc[test['target'] == 1,'target_id'] = 'Company'
test.loc[test['target'] == 2,'target_id'] = 'EducationalInstitution'
test.loc[test['target'] == 3,'target_id'] = 'Artist'
test.loc[test['target'] == 4,'target_id'] = 'Athlete'
test.loc[test['target'] == 5,'target_id'] = 'OfficeHolder'
test.loc[test['target'] == 6,'target_id'] = 'MeanOfTransportation'
test.loc[test['target'] == 7,'target_id'] = 'Building'
test.loc[test['target'] == 8,'target_id'] = 'NaturalPlace'
test.loc[test['target'] == 9,'target_id'] = 'Village'
test.loc[test['target'] == 10,'target_id'] = 'Animal'
test.loc[test['target'] == 11,'target_id'] = 'Plant'
test.loc[test['target'] == 12,'target_id'] = 'Album'
test.loc[test['target'] == 13,'target_id'] = 'Film'
test.loc[test['target'] == 14,'target_id'] = 'WrittenWork'
# Out:
# /home/msc2/.local/lib/python3.6/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/msc2/.local/lib/python3.6/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
import numpy as np

# %%
X_test = test['content']
y_test = test['target_id']

predicted_data = clf.predict(count_vect.transform(X_test))
accuracy = np.mean(predicted_data == y_test)
accuracy
# Out:
# 0.9329142857142857

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix


Train_accuracy = accuracy_score(y_train, clf.predict(X_train_tfidf))
Train_accuracy
# Out:
# 0.9638232142857143

# %%
Test_accuracy = accuracy_score(y_test, predicted_data)
Test_accuracy
# Out:
# 0.9329142857142857

# %%
conf = confusion_matrix(y_test, predicted_data)
conf
# Out:
# array([[4944,    0,   18,    1,    1,    3,    1,   13,    2,    0,    0,
#            1,    0,   16],
#        [   2, 4443,   21,   42,    5,    6,    0,    0,   11,    5,   15,
#          438,    0,   12],
#        [ 215,    7, 4109,   46,   31,   46,   34,   68,   26,   12,  108,
#           16,   20,  262],
#        [  60,    4,   68, 4545,   12,   27,   19,   35,  139,   14,   30,
#           12,   16,   19],
#        [   2,    2,    6,    1, 4776,   55,   81,    1,   23,   36,    6,
#            2,    1,    8],
#        [ 127,    2,   40,    6,   89, 4419,   54,    9,  102,   10,    9,
#            3,    2,  128],
#        [   0,    0,    4,    1,   42,   45, 4886,    2,    0,    6,    5,
#            1,    1,    7],
#        [  54,    7,   23,    6,    7,   14,   10, 4616,   24,    3,    2,
#            5,    4,  225],
#        [   1,    1,    2,    0,   11,   48,    4,    2, 4918,    4,    2,
#            2,    2,    3],
#        [   5,    2,    1,    1,   71,    2,    4,    4,   16, 4862,    5,
#           13,    9,    5],
#        [  39,    5,  102,   25,   23,   29,   52,   60,   32,   22, 4543,
#           19,   23,   26],
#        [   4,   24,    3,    0,    6,   18,    2,    0,    2,    1,    0,
#         4933,    3,    4],
#        [   8,    1,  123,    2,  112,    3,   24,   45,    0,  129,    8,
#            2, 4541,    2],
#        [  17,    1,   24,    5,   12,   72,   17,   59,    5,    3,    9,
#            4,    3, 4769]])

# %%
roc_auc(predicted_data)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   from ipykernel import kernelapp as app

# %%
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline

classifier = LinearSVC()

text_clf = Pipeline([('vect', CountVectorizer()),('tfidf', TfidfTransformer()),('clf', classifier),])
text_clf.fit(X_train, y_train)

predicted_data = text_clf.predict(X_test)
accuracy= np.mean(predicted_data == y_test)
accuracy
# Out:
# 0.9464285714285714

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix


Train_accuracy = accuracy_score(y_train, clf.predict(X_train_tfidf))
Train_accuracy
# Out:
# 0.9638232142857143

# %%
Test_accuracy = accuracy_score(y_test, predicted_data)
Test_accuracy
# Out:
# 0.9464285714285714

# %%
conf = confusion_matrix(y_test, predicted_data)
conf
# Out:
# array([[4928,    8,   21,    1,    2,    9,    0,   17,    1,    2,    0,
#            1,    0,   10],
#        [   0, 4959,    1,    0,    0,    2,    0,    0,    1,    7,    1,
#           28,    0,    1],
#        [  54,  158, 4475,   18,   17,   91,   26,   23,   13,    2,   43,
#            6,    0,   74],
#        [   3,  286,   35, 4565,    5,   63,    6,    9,    5,    2,   12,
#            3,    0,    6],
#        [   2,    8,    1,    0, 4772,   63,   63,    2,   15,   48,    4,
#            1,   17,    4],
#        [  13,   10,   11,    3,   40, 4754,   47,   10,   38,    8,   11,
#            9,    2,   44],
#        [   0,    5,    0,    0,   37,   40, 4897,    2,    0,    6,    5,
#            2,    2,    4],
#        [  31,   56,   13,    1,    1,   23,    6, 4796,   15,    2,    3,
#            5,    2,   46],
#        [   3,   13,    2,    1,    8,   72,    2,    1, 4886,    5,    4,
#            2,    0,    1],
#        [   6,   28,    3,    0,   13,    7,    0,    0,    1, 4929,    1,
#            2,    9,    1],
#        [   8,  197,  148,   19,   39,   83,   60,   12,   11,    9, 4398,
#            5,    2,    9],
#        [   0,   82,    0,    0,    0,   17,    0,    0,    0,    3,    1,
#         4897,    0,    0],
#        [   9,  664,   15,    0,   84,   35,    2,    1,    1,   21,    5,
#            1, 4161,    1],
#        [   8,   14,   30,    4,    5,   36,    5,   48,    4,    3,    8,
#            2,    0, 4833]])

# %%
roc_auc(predicted_data)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   from ipykernel import kernelapp as app

# %% [markdown]
# <h4> Base line models considered are NaiveBayesian(Multinomial) , SVM

# %% [markdown]
# <h5>TF-IDF VECTORIZER

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


Tfidf_vect = TfidfVectorizer(max_features=50000)
Tfidf_vect.fit(X_train)
Train_X_Tfidf = Tfidf_vect.transform(X_train)
Test_X_Tfidf = Tfidf_vect.transform(X_test)

# %%
print(Tfidf_vect.vocabulary_)
# Out:
# {'bbott': 10241, 'of': 32074, 'arnham': 7751, 'imited': 24449, 'was': 48706, 'ritish': 40282, 'business': 11057, 'based': 10179, 'in': 24582, 'urrey': 47569, 'trading': 45032, 'under': 46789, 'that': 44498, 'name': 30197, 'from': 20123, '1929': 946, 'major': 28938, 'part': 36183, 'their': 44508, 'output': 35609, 'subcontract': 43535, 'to': 44813, 'motor': 29952, 'vehicle': 48267, 'manufacturers': 29025, 'heir': 21633, 'closed': 12151, '1972': 1038, 'is': 25810, 'erman': 17848, 'maker': 28947, 'pens': 36424, 'for': 19890, 'writing': 49211, 'colouring': 12343, 'and': 5929, 'cosmetics': 12976, 'as': 8244, 'well': 48845, 'markers': 29073, 'office': 32093, 'use': 47701, 'the': 44500, 'worlds': 49163, 'largest': 27220, 'manufacturer': 29024, 'oss': 35028, 'workshop': 49155, 'olish': 32616, 'company': 12465, 'located': 28345, 'ozna': 36002, 'specializes': 42816, 'production': 37468, 'accessories': 2867, 'various': 48233, 'games': 20282, 'roleplaying': 40633, 'tabletop': 43939, 'wargames': 48686, 'hey': 21863, 'also': 5201, 'run': 41195, 'an': 5760, 'online': 33507, 'retail': 39630, 'store': 43323, 'active': 3164, 'forum': 19970, 'established': 18374, '2001': 1206, 'by': 11089, 'student': 43483, 'sold': 42660, 'its': 26232, 'products': 37473, 'via': 48404, 'auction': 9224, 'services': 41928, 'but': 11066, '2005': 1246, 'website': 48793, 'arvell': 8181, 'oftware': 32128, 'olutions': 32869, 'srael': 43015, 'known': 26861, 'omputer': 33201, 'ommunications': 33126, 'before': 10318, '2007': 1266, 'wholly': 48940, 'owned': 35864, 'subsidiary': 43588, 'echnology': 15168, 'roup': 40909, 'local': 28335, 'area': 7298, 'network': 30603, 'technologies': 44259, 'ercy': 17673, 'edical': 15380, 'enter': 17206, 'hospital': 22573, 'maha': 28914, 'ebraska': 15095, 'ealth': 14809, 'ystem': 49786, 'he': 21514, 'uide': 46267, 'contacts': 12762, 'directory': 14103, 'careers': 11333, 'guide': 20831, 'music': 30121, 'industry': 24793, 'ounded': 35408, '2003': 1226, 'first': 19664, 'published': 37696, 'printed': 37391, 'became': 10294, 'only': 33509, 'resource': 39555, 'ovember': 35674, '2011': 1308, 'ithin': 26174, 'sports': 42955, 'played': 36824, 'at': 8744, 'international': 25281, 'competitive': 12496, 'level': 27790, 'est': 18371, 'orld': 34486, 'refers': 39059, 'team': 44223, 'players': 36828, 'many': 29031, 'countries': 13046, 'origin': 34410, 'compete': 12488, 'against': 3648, 'single': 42342, 'individual': 24752, 'or': 34131, 'group': 20795, 'such': 43635, 'club': 12167, 'country': 13048, 'formed': 19941, '1998': 1166, 'multinational': 30081, 'assachusetts': 8524, 'ublin': 45771, 'reland': 39189, 'providing': 37627, 'cloudbased': 12162, 'software': 42651, 'service': 41924, 'human': 22792, 'capital': 11281, 'management': 28978, 'solutions': 42675, 'ts': 45369, 'social': 42624, 'recognition': 38874, 'are': 7297, 'designed': 13891, 'employees': 16681, 'recognize': 38876, 'reward': 39743, 'each': 14717, 'other': 35181, 'incentive': 24637, 'performance': 36466, 'behaviors': 10330, 'mapped': 29035, 'values': 48184, 'private': 37412, 'corporation': 12950, 'omanian': 32939, 'oil': 32302, 'operates': 34024, 'throughout': 44683, 'urope': 47526, 'primarily': 37363, 'refining': 39063, 'marketing': 29079, 'with': 49071, 'additional': 3268, 'operations': 34030, 'exploration': 19091, 'drilling': 14550, 'transportation': 45122, 'ave': 9516, 'brand': 10823, 'suite': 43666, 'small': 42563, 'legal': 27625, 'ccounting': 11501, 'nc': 30308, 'headquartered': 21528, 'neighbourhood': 30555, 'oronto': 34593, 'anada': 5765, 'currently': 13416, 'being': 10339, 'used': 47702, '200': 1195, 'countrieshe': 13047, 'companys': 12468, 'product': 37467, 'free': 20066, 'accounting': 2909, 'businesses': 11058, '19': 895, 'ussian': 47803, 'named': 30198, 'after': 3629, 'companies': 12461, 'one': 33340, 'integrated': 25205, 'circuits': 12009, 'astern': 8656, 'uropehe': 47529, 'includes': 24661, 'parent': 36151, 'design': 13887, 'manufacturing': 29027, 'electronic': 16144, 'semiconductors' ...

# %%
from sklearn import model_selection, naive_bayes, svm

Naive = naive_bayes.MultinomialNB()
Naive.fit(Train_X_Tfidf,y_train)
# predict the labels on validation dataset
predictions_NB = Naive.predict(Test_X_Tfidf)

# %%
predictions_NB
# Out:
# array(['Company', 'Company', 'Company', ..., 'WrittenWork', 'WrittenWork',
#        'WrittenWork'], dtype='<U22')

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix


Train_accuracy = accuracy_score(y_train, clf.predict(X_train_tfidf))
Train_accuracy
# Out:
# 0.9638232142857143

# %%
Accuracy = accuracy_score(predictions_NB, y_test)*100
Accuracy
# Out:
# 92.52142857142857

# %%
roc_auc(predicted_data)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   from ipykernel import kernelapp as app

# %%
SVM = LinearSVC()
SVM.fit(Train_X_Tfidf,y_train)
predictions_SVM = SVM.predict(Test_X_Tfidf)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix


Train_accuracy = accuracy_score(y_train, clf.predict(X_train_tfidf))
Train_accuracy
# Out:
# 0.9638232142857143

# %%
Accuracy = accuracy_score(predictions_SVM, y_test)*100
Accuracy
# Out:
# 94.59857142857143

# %%
roc_auc(predicted_data)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   from ipykernel import kernelapp as app

# %% [markdown]
# <h5> Removing stop_words and other pre-processing works

# %%
import re
from bs4 import BeautifulSoup
replace_symbols= re.compile('[/(){}\[\]\|@,;]')
other_symbols = re.compile('[^0-9a-z #+_]')
def clean_text(text):
    text = replace_symbols.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = other_symbols.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    return text
train_data['content'] = train_data['content'].apply(clean_text)

# %%
train_data['content'].dropna(inplace=True)
train_data['content'] = [entry.lower() for entry in train_data['content']]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
X_train = train_data['content']
y_train = train_data['target_id']


count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
X_test = test['content']
y_test = test['target_id']

predicted_data = clf.predict(count_vect.transform(X_test))
accuracy = np.mean(predicted_data == y_test)
accuracy
# Out:
# 0.9329142857142857

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix


Train_accuracy = accuracy_score(y_train, clf.predict(X_train_tfidf))
Train_accuracy
# Out:
# 0.9638232142857143

# %%
Test_accuracy = accuracy_score(y_test, predicted_data)
Test_accuracy
# Out:
# 0.9464285714285714

# %%
conf = confusion_matrix(y_test, predicted_data)
conf
# Out:
# array([[4928,    8,   21,    1,    2,    9,    0,   17,    1,    2,    0,
#            1,    0,   10],
#        [   0, 4959,    1,    0,    0,    2,    0,    0,    1,    7,    1,
#           28,    0,    1],
#        [  54,  158, 4475,   18,   17,   91,   26,   23,   13,    2,   43,
#            6,    0,   74],
#        [   3,  286,   35, 4565,    5,   63,    6,    9,    5,    2,   12,
#            3,    0,    6],
#        [   2,    8,    1,    0, 4772,   63,   63,    2,   15,   48,    4,
#            1,   17,    4],
#        [  13,   10,   11,    3,   40, 4754,   47,   10,   38,    8,   11,
#            9,    2,   44],
#        [   0,    5,    0,    0,   37,   40, 4897,    2,    0,    6,    5,
#            2,    2,    4],
#        [  31,   56,   13,    1,    1,   23,    6, 4796,   15,    2,    3,
#            5,    2,   46],
#        [   3,   13,    2,    1,    8,   72,    2,    1, 4886,    5,    4,
#            2,    0,    1],
#        [   6,   28,    3,    0,   13,    7,    0,    0,    1, 4929,    1,
#            2,    9,    1],
#        [   8,  197,  148,   19,   39,   83,   60,   12,   11,    9, 4398,
#            5,    2,    9],
#        [   0,   82,    0,    0,    0,   17,    0,    0,    0,    3,    1,
#         4897,    0,    0],
#        [   9,  664,   15,    0,   84,   35,    2,    1,    1,   21,    5,
#            1, 4161,    1],
#        [   8,   14,   30,    4,    5,   36,    5,   48,    4,    3,    8,
#            2,    0, 4833]])

# %%
roc_auc(predicted_data)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   from ipykernel import kernelapp as app

# %%
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline

classifier = LinearSVC()

clf = Pipeline([('vect', CountVectorizer()),('tfidf', TfidfTransformer()),('clf', classifier),])
clf.fit(X_train, y_train)

predicted_data = clf.predict(X_test)
accuracy= np.mean(predicted_data == y_test)
accuracy
# Out:
# 0.9464285714285714

# %%
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline

classifier = LinearSVC()

text_clf = Pipeline([('vect', CountVectorizer()),('tfidf', TfidfTransformer()),('clf', classifier),])
text_clf.fit(X_train, y_train)

predicted_data = text_clf.predict(X_test)
accuracy= np.mean(predicted_data == y_test)
accuracy
# Out:
# 0.9464285714285714

# %%
Test_accuracy = accuracy_score(y_test, predicted_data)
Test_accuracy
# Out:
# 0.9464285714285714

# %%
conf = confusion_matrix(y_test, predicted_data)
conf
# Out:
# array([[4928,    8,   21,    1,    2,    9,    0,   17,    1,    2,    0,
#            1,    0,   10],
#        [   0, 4959,    1,    0,    0,    2,    0,    0,    1,    7,    1,
#           28,    0,    1],
#        [  54,  158, 4475,   18,   17,   91,   26,   23,   13,    2,   43,
#            6,    0,   74],
#        [   3,  286,   35, 4565,    5,   63,    6,    9,    5,    2,   12,
#            3,    0,    6],
#        [   2,    8,    1,    0, 4772,   63,   63,    2,   15,   48,    4,
#            1,   17,    4],
#        [  13,   10,   11,    3,   40, 4754,   47,   10,   38,    8,   11,
#            9,    2,   44],
#        [   0,    5,    0,    0,   37,   40, 4897,    2,    0,    6,    5,
#            2,    2,    4],
#        [  31,   56,   13,    1,    1,   23,    6, 4796,   15,    2,    3,
#            5,    2,   46],
#        [   3,   13,    2,    1,    8,   72,    2,    1, 4886,    5,    4,
#            2,    0,    1],
#        [   6,   28,    3,    0,   13,    7,    0,    0,    1, 4929,    1,
#            2,    9,    1],
#        [   8,  197,  148,   19,   39,   83,   60,   12,   11,    9, 4398,
#            5,    2,    9],
#        [   0,   82,    0,    0,    0,   17,    0,    0,    0,    3,    1,
#         4897,    0,    0],
#        [   9,  664,   15,    0,   84,   35,    2,    1,    1,   21,    5,
#            1, 4161,    1],
#        [   8,   14,   30,    4,    5,   36,    5,   48,    4,    3,    8,
#            2,    0, 4833]])

# %%
roc_auc(predicted_data)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   from ipykernel import kernelapp as app

# %% [markdown]
# <h3>Using both types of Vectorizers we are getting the maximum accuracy for the SVM classifier

# %% [markdown]
# <h2>Final Model : SVM Classifier

# %% [markdown]
# <h5> Inputs from Medium Towards_Data_Science Analytics-Vidhya GitHub
